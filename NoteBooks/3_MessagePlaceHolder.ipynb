# %% [markdown]
# #### **Message Place Holder in LangChain**
# ##### *It's Conversation Memory by inserting a list of Messages*

# %% [markdown]
# #### **Set and Load the API Key**

# %%
import os
from dotenv import load_dotenv
load_dotenv()

if os.environ['GROQ_API_KEY']:
    print("API Key is Set")
# Out:
# API Key is Set

# %% [markdown]
# ### **Create a LLM Model using Groq Model**

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model = "openai/gpt-oss-120b"
)

llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.5.4', 'langchain': '1.3.15'}}, profile={'name': 'GPT OSS 120B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000002999D6F2030>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002999D842900>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %% [markdown]
# #### ***Design a Prompt***

# %%
from langchain_core.prompts import ChatPromptTemplate,MessagesPlaceholder
from langchain_core.messages import SystemMessage,HumanMessage,AIMessage

prompt_template = ChatPromptTemplate.from_messages([
    ("system","You are an helpful Assistant"),
    MessagesPlaceholder(variable_name="chat_history"),
    ("human","{question}")
])

chat_history = [
    HumanMessage(content = "What is LangChain?"),
    AIMessage(content = "LangChain is an Open Source Frame Work that build application powered by LLM.")
]

prompt = prompt_template.invoke({
    "chat_history":chat_history,
    "question":"Why do we need it?"
})

# %%
response = llm.invoke(prompt)

print(response.content)
# Out:
# ### Why LangChain is useful (and often needed)
#
# | Problem you face when building LLM‑powered software | How LangChain helps you solve it |
# |------------------------------------------------------|----------------------------------|
# | **Orchestrating many LLM calls** – you need to call a model, then feed its output to another model, a tool, or a database. | **Chains** let you declaratively connect prompts, models, and other components into a single reusable pipeline (e.g., *LLM → PromptTemplate → Retriever → LLM*). |
# | **Prompt management** – prompts become large, need versioning, templating, and dynamic insertion of variables. | **PromptTemplates** and **PromptTemplates with partials** let you store prompts as code‑friendly strings, inject variables safely, and reuse them across projects. |
# ...
