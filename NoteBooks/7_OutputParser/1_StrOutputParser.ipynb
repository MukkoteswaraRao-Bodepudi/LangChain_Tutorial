# %% [markdown]
# #### ***Output Parser***
#
# ##### **Output Parser is a Component used that takes output from llm converts into required format our can use**

# %%
###Load API Key
import os
from dotenv import load_dotenv
load_dotenv()

if os.environ['GROQ_API_KEY']:
    print("API Key is Set")
# Out:
# API Key is Set

# %%
### Create LLM
from langchain_groq import ChatGroq

llm = ChatGroq(
    model = "openai/gpt-oss-120b"
)

llm
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.5.4', 'langchain': '1.3.15'}}, profile={'name': 'GPT OSS 120B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x000002C6A8ED89E0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002C6A8948980>, model_name='openai/gpt-oss-120b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
### Design a Simple Prompt
from langchain_core.prompts.prompt import PromptTemplate

prompt_template = PromptTemplate.from_template("""
    You are an {domain} expert. Can you please about {topic} in user-friendly way.
""")

# %%
### Output Parser
from langchain_core.output_parsers import StrOutputParser

parser = StrOutputParser()

# %%
## Chain
chain = prompt_template | llm | parser

response = chain.invoke({
    "domain":"AI",
    "topic":"RAG"
})
print(response)
# Out:
# ## Retrieval‑Augmented Generation (RAG) – A Friendly Overview
#
# Imagine you’re writing a research paper. You have two tools at your disposal:
#
# 1. **Your own knowledge** – the things you already know and can write about from memory.
# 2. **A library** – you can quickly look up facts, quotes, or data you don’t remember off‑hand.
#
# **Retrieval‑Augmented Generation (RAG)** is the AI version of that combo. It lets a language model (the “knowledge” part) **pull in up‑to‑date or specialized information from an external source** (the “library”) **right when it’s generating text**. The result is answers that are both fluent *and* grounded in real data.
#
# ---
#
# ## 1. The Two Core Pieces
#
# | Piece | What It Does | Real‑World Analogy |
# |------|--------------|--------------------|
# | **Retriever** | Searches a large collection (documents, webpages, databases, PDFs, etc.) and returns the most relevant chunks of text. | A librarian who quickly fetches the books or articles you need. |
# | **Generator** | Takes the retrieved chunks (plus your prompt) and writes a response, weaving the facts into natural language. | The writer who reads the fetched material and crafts a coherent paragraph. |
#
# The whole pipeline looks like this:
#
# ```
# User Prompt → Retriever → Relevant Passages → Generator → Final Answer
# ```
#
# ---
#
# ## 2. Why RAG Matters
#
# | Problem with “plain” LLMs | How RAG helps |
# |---------------------------|----------------|
# | **Stale knowledge** – models are trained on data that’s months/years old. | Pulls in fresh information from the latest documents or APIs. |
# | **Hallucinations** – the model may make up facts to sound confident. | Answers are anchored to actual retrieved text, reducing false statements. |
# | **Domain‑specific expertise** – a general‑purpose model may not know niche jargon. | You can feed it a curated knowledge base (e.g., legal contracts, medical guidelines). |
# | **Explainability** – it’s hard to trace *why* a model said something. | You can show the exact passages it used, giving users a clear audit trail. |
#
# ---
#
# ## 3. A Simple Analogy: The “Chef + Cookbook” Model
#
# - **Chef (Generator)**: Knows cooking techniques, can improvise, and writes tasty recipes.
# - **Cookbook (Retriever)**: Contains specific recipes, ingredient lists, and regional variations.
#
# When a customer asks, “How do I make a vegan lasagna that’s gluten‑free?” the chef first flips through the cookbook to find relevant recipes, then combines that knowledge with his own expertise to create a custom, accurate answer. The dish is both creative (fluent) **and** correct (grounded).
#
# ---
#
# ## 4. Typical Workflow (Step‑by‑Step)
#
# 1. **Build / Choose a Knowledge Base**
#    - Text files, PDFs, web pages, API responses, product catalogs, etc.
#    - Store them in a searchable index (vector DB, BM25, hybrid).
#
# 2. **Embed the Documents**
#    - Convert each chunk (e.g., 200‑400 words) into a dense vector using an embedding model (e.g., OpenAI’s `text‑embedding‑ada‑002`, Sentence‑Transformers, etc.).
#
# 3. **Store in a Retrieval Engine**
#    - Options: Pinecone, Weaviate, Milvus, Elastic Search, Qdrant, or even a simple FAISS index on your own server.
#
# 4. **User Prompt Arrives**
#    - Example: “What are the latest COVID‑19 vaccination guidelines for travelers?”
#
# 5. **Retriever Runs**
#    - Convert the prompt into an embedding.
#    - Search the index for the top‑k most similar chunks (k = 3‑10 is common).
#
# 6. **Rerank (Optional)**
#    - Use a lightweight cross‑encoder to order the chunks by relevance.
#
# 7. **Pass to Generator**
#    - Build a prompt that includes:
#      ```text
#      Context:
#      [Chunk 1]
#      [Chunk 2]
#      …
#
#      Question:
#      What are the latest COVID‑19 vaccination guidelines for travelers?
#      ```
#    - Send to a language model (GPT‑4, Claude, Llama‑2, etc.) with a system instruction like “Answer using only the information above. Cite the source if possible.”
#
# 8. **Post‑process**
#    - Strip out the raw context (if you don’t want it shown).
#    - Add citations, footnotes, or links back to the original documents.
#
# 9. **Return to User**
#    - The answer feels natural **and** you can point the user to the exact source.
#
# ---
#
# ## 5. Quick‑Start Code Sketch (Python)
#
# Below is a minimal example using **OpenAI embeddings**, **FAISS** for similarity search, and **OpenAI’s GPT‑4** for generation. (You can swap any component for an open‑source alternative.)
#
# ```python
# import os, json, faiss, openai
# from tqdm import tqdm
# from pathlib import Path
#
# openai.api_key = os.getenv("OPENAI_API_KEY")
#
# # 1️⃣ Load & chunk your documents
# def load_and_chunk(folder, chunk_size=300):
#     docs = []
#     for file in Path(folder).glob("*.txt"):
#         text = file.read_text()
#         # naive split on sentences (you can use more sophisticated chunkers)
#         words = text.split()
#         for i in range(0, len(words), chunk_size):
#             chunk = " ".join(words[i:i+chunk_size])
#             docs.append({"source": str(file), "text": chunk})
#     return docs
#
# docs = load_and_chunk("knowledge_base/")
#
# # 2️⃣ Embed each chunk
# def embed_texts(texts):
#     # OpenAI batch endpoint (max 2048 tokens per request)
#     resp = openai.Embedding.create(
#         model="text-embedding-ada-002",
#         input=texts
#     )
#     return [e["embedding"] for e in resp["data"]]
#
# embeddings = embed_texts([d["text"] for d in docs])
#
# # 3️⃣ Build a FAISS index
# dim = len(embeddings[0])
# index = faiss.IndexFlatL2(dim)          # simple L2 index
# index.add(np.array(embeddings).astype('float32'))
#
# # 4️⃣ Retrieval function
# def retrieve(query, k=5):
#     q_emb = embed_texts([query])[0]
#     D, I = index.search(np.array([q_emb]).astype('float32'), k)
#     return [docs[i] for i in I[0]]
#
# # 5️⃣ Generation function
# def generate_answer(query, retrieved):
#     context = "\n\n".join([f"[{i+1}] {c['text']}" for i, c in enumerate(retrieved)])
#     system_prompt = "You are an assistant that answers using only the provided context. Cite the source numbers."
#     user_prompt = f"""Context:
# {context}
#
# Question: {query}
# Answer (include citations like [1], [2] as needed):"""
#     resp = openai.ChatCompletion.create(
#         model="gpt-4o-mini",
#         messages=[
#             {"role": "system", "content": system_prompt},
#             {"role": "user",   "content": user_prompt}
#         ],
#         temperature=0.2
#     )
#     return resp["choices"][0]["message"]["content"]
#
# # 🎉 Example usage
# query = "What are the key steps for safely disposing of lithium‑ion batteries?"
# retrieved = retrieve(query, k=4)
# answer = generate_answer(query, retrieved)
# print(answer)
# ```
#
# **What this does:**
#
# 1. Splits every `.txt` file in `knowledge_base/` into bite‑size chunks.
# 2. Turns each chunk into a 1536‑dimensional vector with OpenAI embeddings.
# 3. Stores vectors in a FAISS index for fast similarity search.
# 4. When a user asks a question, we retrieve the most relevant chunks.
# 5. We feed those chunks (as “context”) plus the question to GPT‑4, asking it to cite the chunk numbers.
#
# You can replace:
#
# - **Embedding model** → `sentence‑transformers/all-MiniLM-L6-v2` (open‑source).
# - **Vector DB** → Pinecone, Weaviate, Qdrant, or Elasticsearch.
# - **LLM** → Llama‑3‑8B‑Instruct, Mistral‑7B‑Instruct, Claude, etc.
#
# ---
#
# ## 6. Real‑World Use Cases
#
# | Domain | How RAG Helps |
# |--------|---------------|
# | **Customer Support** | Pull the latest policy docs, troubleshooting guides, or warranty terms to answer tickets without manually updating the model. |
# | **Healthcare** | Retrieve up‑to‑date clinical guidelines, drug interaction tables, or patient records (with privacy safeguards) before generating advice. |
# | **Legal** | Search a firm’s contract repository, statutes, or case law, then draft memos that reference exact clauses. |
# | **Education** | Combine a textbook index with a tutoring LLM, giving students answers that cite textbook pages. |
# | **E‑commerce** | Look up product specs, inventory levels, or shipping policies to answer shopper questions accurately. |
# | **Research** | Query a corpus of scientific papers and get concise summaries that include citations. |
#
# ---
#
# ## 7. Common Pitfalls & Tips
#
# | Pitfall | Why It Happens | Quick Fix |
# |---------|----------------|-----------|
# | **“Hallucinated citations”** – the generator mentions a source that wasn’t in the retrieved set. | Model tries to sound confident even when context is insufficient. | Use a *strict* system prompt: “Only answer using the provided context. If you can’t answer, say *I don’t know*.” |
# | **Too‑large context** – the LLM runs out of token budget. | Adding many chunks blows up prompt length. | Retrieve a small, high‑quality set (k=3‑5) and optionally *summarize* each chunk before feeding it in. |
# | **Stale index** – your knowledge base changes but the vector store isn’t updated. | Forgetting to re‑embed new documents. | Set up an automated pipeline that re‑indexes nightly or on each document upload. |
# | **Semantic drift** – embeddings retrieve loosely related text, leading to irrelevant answers. | Embedding model not tuned for your domain. | Use a domain‑specific embedding model (e.g., BioBERT for biomedical text) or hybrid retrieval (BM25 + vectors). |
# | **Privacy leaks** – sensitive data ends up in the prompt sent to a hosted LLM. | Sending raw user documents to an external API. | Mask or redact PII before embedding, or run the generator **in‑house** with an open‑source model. |
#
# ---
#
# ## 8. How to Choose the Right Stack
#
# | Decision | Options | When to Pick |
# |----------|---------|--------------|
# | **Embedding Model** | OpenAI `text-embedding-ada-002` (fast, high quality) • Sentence‑Transformers (free, customizable) • Proprietary domain models (e.g., `jina‑embeddings-v2`) | If you need zero‑setup and good general performance → OpenAI. If you’re on a budget or need domain tuning → open‑source. |
# | **Vector Store** | FAISS (local, simple) • Pinecone/Weaviate/Qdrant (managed, scaling, metadata) • Elastic (hybrid search) | Small prototype → FAISS. Production with many users → managed DB. Need complex filters (date, tags) → Elastic/Weaviate. |
# | **Generator** | GPT‑4 / Claude (high quality, cost) • Llama‑3‑8B‑Instruct (free, on‑prem) • Mistral‑7B (compact) | If you can afford API calls and need best‑in‑class output → GPT‑4. If you need data‑privacy or low cost → self‑hosted open‑source. |
# | **Reranker (optional)** | Cross‑encoder from `sentence‑transformers` • OpenAI `gpt‑4o-mini` as a “re‑ask” | When top‑k retrieval returns noisy results. |
#
# ---
#
# ## 9. TL;DR Cheat Sheet
#
# - **RAG = Retriever + Generator**
# - **Goal:** Give LLMs up‑to‑date, factual, domain‑specific answers.
# - **How it works:**
#   1. Store your docs → embed → index.
#   2. Query → embed → nearest‑neighbor search → get relevant chunks.
#   3. Prompt LLM with those chunks + user question.
#   4. LLM writes a fluent answer, ideally citing the chunks.
# - **Benefits:** Freshness, reduced hallucinations, explainable citations, easy domain adaptation.
# - **Gotchas:** Keep the index fresh, limit context size, enforce “use only provided info” in the prompt, protect privacy.
#
# ---
#
# ### Want to Try It Yourself?
#
# 1. **Pick a small knowledge base** (e.g., a folder of a few PDFs or markdown files).
# 2. **Follow the code snippet** above (swap in your own API keys).
# 3. **Ask a question** that you know the answer to—see how the model cites the source.
# 4. **Iterate:** change `k`, try a reranker, or switch to an open‑source LLM to see the trade‑offs.
#
# Happy building! 🚀 If you run into any roadblocks or want recommendations for specific tools (e.g., “Which vector DB works best on Azure?”), just let me know!
